# %% [markdown]
# PANDAS

# %%
import pandas as pd

# %%
# !ls
# Out:
# drive  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !pwd
# Out:
# /content

# %%
df=pd.read_csv("/content/drive/MyDrive/excel files/survey_results_public.csv")

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df.head(100)
# Out:
#     Respondent                                       Professional  \
# 0            1                                            Student
# 1            2                                            Student
# 2            3                             Professional developer
# 3            4  Professional non-developer who sometimes write...
# 4            5                             Professional developer
# ..         ...                                                ...
# 95          96                             Professional developer
# 96          97                             Professional developer
# 97          98                             Professional developer
# 98          99                                            Student
# 99         100                             Professional developer
#
#                                  ProgramHobby         Country      University  \
# 0                                   Yes, both   United States              No
# ...

# %%
df.head(2)
# Out:
#    Respondent Professional ProgramHobby         Country      University  \
# 0           1      Student    Yes, both   United States              No
# 1           2      Student    Yes, both  United Kingdom  Yes, full-time
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
#
#                              MajorUndergrad  \
# 0                                       NaN
# 1  Computer science or software engineering
#
#                               HomeRemote         CompanySize  ...  \
# 0                                    NaN                 NaN  ...
# 1  More than half, but not all, the time  20 to 99 employees  ...
#
#   StackOverflowMakeMoney Gender HighestEducationParents  \
# ...

# %%
df.shape
# Out:
# (51392, 154)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 60.4+ MB

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
pd.set_option("display.max_columns",154)

# %%
df
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# ...           ...                                                ...
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                     ProgramHobby         Country      University  \
# 0                      Yes, both   United States              No
# ...

# %%
pd.set_option("display.min_rows",12)

# %%
df
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# 5               6                                            Student
# ...           ...                                                ...
# 51386       51387                             Professional developer
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
# ...

# %%
schema_df=pd.read_csv("/content/drive/MyDrive/excel files/survey_results_schema.csv")

# %%
schema_df
# Out:
#                    Column                                           Question
# 0              Respondent                               Respondent ID number
# 1            Professional         Which of the following best describes you?
# 2            ProgramHobby  Do you program as a hobby or contribute to ope...
# 3                 Country            In which country do you currently live?
# 4              University  Are you currently enrolled in a formal, degree...
# 5        EmploymentStatus  Which of the following best describes your cur...
# ..                    ...                                                ...
# 148            SurveyLong                           This survey was too long
# 149  QuestionsInteresting                     The questions were interesting
# 150    QuestionsConfusing                       The questions were confusing
# 151     InterestedAnswers  I'm interested in learning how other developer...
# ...

# %%
schema_df["Question"]
# Out:
# 0                                   Respondent ID number
# 1             Which of the following best describes you?
# 2      Do you program as a hobby or contribute to ope...
# 3                In which country do you currently live?
# 4      Are you currently enrolled in a formal, degree...
# 5      Which of the following best describes your cur...
#                              ...
# 148                             This survey was too long
# 149                       The questions were interesting
# 150                         The questions were confusing
# 151    I'm interested in learning how other developer...
# 152    What is your current annual base salary, befor...
# 153    You said before that you are currently learnin...
# Name: Question, Length: 154, dtype: object

# %%
schema_df["Column"]
# Out:
# 0                Respondent
# 1              Professional
# 2              ProgramHobby
# 3                   Country
# 4                University
# 5          EmploymentStatus
#                ...
# 148              SurveyLong
# 149    QuestionsInteresting
# 150      QuestionsConfusing
# 151       InterestedAnswers
# 152                  Salary
# 153          ExpectedSalary
# Name: Column, Length: 154, dtype: object

# %%
pd.set_option("display.max_rows",200)

# %%
schema_df
# Out:
#                                Column  \
# 0                          Respondent
# 1                        Professional
# 2                        ProgramHobby
# 3                             Country
# 4                          University
# 5                    EmploymentStatus
# 6                     FormalEducation
# 7                      MajorUndergrad
# 8                          HomeRemote
# 9                         CompanySize
# 10                        CompanyType
# 11                       YearsProgram
# 12                      YearsCodedJob
# 13                  YearsCodedJobPast
# 14                      DeveloperType
# 15                   WebDeveloperType
# 16                MobileDeveloperType
# 17                   NonDeveloperType
# 18                 CareerSatisfaction
# 19                    JobSatisfaction
# 20                      ExCoderReturn
# 21                    ExCoderNotForMe
# 22                     ExCoderBalance
# ...

# %%
schema_df.tail()
# Out:
#                    Column                                           Question
# 149  QuestionsInteresting                     The questions were interesting
# 150    QuestionsConfusing                       The questions were confusing
# 151     InterestedAnswers  I'm interested in learning how other developer...
# 152                Salary  What is your current annual base salary, befor...
# 153        ExpectedSalary  You said before that you are currently learnin...

# %%
df
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# 5               6                                            Student
# ...           ...                                                ...
# 51386       51387                             Professional developer
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
# ...

# %%
df["Professional"]
# Out:
# 0                                                  Student
# 1                                                  Student
# 2                                   Professional developer
# 3        Professional non-developer who sometimes write...
# 4                                   Professional developer
# 5                                                  Student
#                                ...
# 51386                               Professional developer
# 51387                               Professional developer
# 51388                                              Student
# 51389                               Professional developer
# 51390                               Professional developer
# 51391    Professional non-developer who sometimes write...
# Name: Professional, Length: 51392, dtype: object

# %%
df.columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)

# %%
df["Salary"]
# Out:
# 0             NaN
# 1             NaN
# 2        113750.0
# 3             NaN
# 4             NaN
# 5             NaN
#            ...
# 51386         NaN
# 51387     58000.0
# 51388         NaN
# 51389         NaN
# 51390     40000.0
# 51391         NaN
# Name: Salary, Length: 51392, dtype: float64

# %%
type(df["Respondent"])
# Out:
# pandas.core.series.Series

# %%
df.Salary
# Out:
# 0             NaN
# 1             NaN
# 2        113750.0
# 3             NaN
# 4             NaN
# 5             NaN
#            ...
# 51386         NaN
# 51387     58000.0
# 51388         NaN
# 51389         NaN
# 51390     40000.0
# 51391         NaN
# Name: Salary, Length: 51392, dtype: float64

# %%
df.iloc[[12,14],[3,5]]
# Out:
#            Country                    EmploymentStatus
# 12  United Kingdom  Not employed, but looking for work
# 14  United Kingdom                  Employed full-time

# %%
df.iloc[[1],4]
# Out:
# 1    Yes, full-time
# Name: University, dtype: object

# %%
df.loc[[1,3]]
# Out:
#    Respondent                                       Professional ProgramHobby  \
# 1           2                                            Student    Yes, both
# 3           4  Professional non-developer who sometimes write...    Yes, both
#
#           Country      University    EmploymentStatus  \
# 1  United Kingdom  Yes, full-time  Employed part-time
# 3   United States              No  Employed full-time
#
#                                      FormalEducation  \
# 1  Some college/university study without earning ...
# 3                                    Doctoral degree
#
#                                   MajorUndergrad  \
# 1       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
#
#                                           HomeRemote  \
# 1              More than half, but not all, the time
# 3  Less than half the time, but at least one day ...
#
#                 CompanySize  \
# 1        20 to 99 employees
# ...

# %%
df.loc[[19,20],["Salary","Country"]]
# Out:
#     Salary Country
# 19     NaN  Greece
# 20     NaN  Brazil

# %%
df.loc[:,["Country"]]
# Out:
#               Country
# 0       United States
# 1      United Kingdom
# 2      United Kingdom
# 3       United States
# 4         Switzerland
# 5         New Zealand
# ...               ...
# 51386         Romania
# 51387   United States
# 51388       Venezuela
# 51389          Canada
# 51390   United States
# 51391         Ireland
#
# [51392 rows x 1 columns]

# %%
df.loc[[2,4],:]
# Out:
#    Respondent            Professional               ProgramHobby  \
# 2           3  Professional developer                  Yes, both
# 4           5  Professional developer  Yes, I program as a hobby
#
#           Country University    EmploymentStatus    FormalEducation  \
# 2  United Kingdom         No  Employed full-time  Bachelor's degree
# 4     Switzerland         No  Employed full-time    Master's degree
#
#                              MajorUndergrad  \
# 2  Computer science or software engineering
# 4  Computer science or software engineering
#
#                                           HomeRemote  \
# 2  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  \
# 2  10,000 or more employees
# 4        10 to 19 employees
#
#                                          CompanyType      YearsProgram  \
# 2                        Publicly-traded corporation  20 or more years
# ...

# %%
df["Salary"].value_counts()
# Out:
# 120000.000000    167
# 110000.000000    164
# 100000.000000    155
# 75000.000000     149
# 60000.000000     139
# 90000.000000     136
#                 ...
# 8494.623656        1
# 45243.750000       1
# 2634.408602        1
# 1238.765432        1
# 66300.000000       1
# 6460.138012        1
# Name: Salary, Length: 3049, dtype: int64

# %%
df["Salary"].value_counts().plot(kind="bar")

# %%
df["Salary"].value_counts().plot(kind="line")

# %%
df["Respondent"].value_counts()
# Out:
# 1        1
# 34266    1
# 34256    1
# 34257    1
# 34258    1
# 34259    1
#         ..
# 17133    1
# 17134    1
# 17135    1
# 17136    1
# 17137    1
# 51392    1
# Name: Respondent, Length: 51392, dtype: int64

# %%
df["Respondent"].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 51386    False
# 51387    False
# 51388    False
# 51389    False
# 51390    False
# 51391    False
# Name: Respondent, Length: 51392, dtype: bool

# %%
df.set_index("Respondent")
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
# 6                                                     Student
# ...                                                       ...
# 51387                                  Professional developer
# 51388                                  Professional developer
# 51389                                                 Student
# 51390                                  Professional developer
# 51391                                  Professional developer
# 51392       Professional non-developer who sometimes write...
#
#                          ProgramHobby         Country      University  \
# ...

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df.set_index("Respondent",inplace=True)

# %%
df
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
# 6                                                     Student
# ...                                                       ...
# 51387                                  Professional developer
# 51388                                  Professional developer
# 51389                                                 Student
# 51390                                  Professional developer
# 51391                                  Professional developer
# 51392       Professional non-developer who sometimes write...
#
#                          ProgramHobby         Country      University  \
# ...

# %%
df.head()
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
#
#                          ProgramHobby         Country      University  \
# Respondent
# 1                           Yes, both   United States              No
# 2                           Yes, both  United Kingdom  Yes, full-time
# 3                           Yes, both  United Kingdom              No
# 4                           Yes, both   United States              No
# 5           Yes, I program as a hobby     Switzerland              No
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# ...

# %%
df.shape
# Out:
# (51392, 153)

# %%
schema_df=pd.read_csv("/content/drive/MyDrive/excel files/survey_results_schema.csv",index_col="Column")

# %%
schema_df
# Out:
#                                                                            Question
# Column
# Respondent                                                     Respondent ID number
# Professional                             Which of the following best describes you?
# ProgramHobby                      Do you program as a hobby or contribute to ope...
# Country                                     In which country do you currently live?
# University                        Are you currently enrolled in a formal, degree...
# EmploymentStatus                  Which of the following best describes your cur...
# FormalEducation                   Which of the following best describes the high...
# MajorUndergrad                    Which of the following best describes your mai...
# HomeRemote                             How often do you work from home or remotely?
# CompanySize                       In terms of the number of employees, how large...
# ...

# %%
schema_df.sort_index()
# Out:
#                                                                            Question
# Column
# AnnoyingUI                                 It annoys me when software has a poor UI
# AssessJobCommute                  When you're assessing potential jobs to apply ...
# AssessJobCompensation             When you're assessing potential jobs to apply ...
# AssessJobDept                     When you're assessing potential jobs to apply ...
# AssessJobDiversity                When you're assessing potential jobs to apply ...
# AssessJobExp                      When you're assessing potential jobs to apply ...
# AssessJobFinances                 When you're assessing potential jobs to apply ...
# AssessJobIndustry                 When you're assessing potential jobs to apply ...
# AssessJobLeaders                  When you're assessing potential jobs to apply ...
# AssessJobOffice                   When you're assessing potential jobs to apply ...
# ...

# %%
schema_df
# Out:
#                                                                            Question
# Column
# Respondent                                                     Respondent ID number
# Professional                             Which of the following best describes you?
# ProgramHobby                      Do you program as a hobby or contribute to ope...
# Country                                     In which country do you currently live?
# University                        Are you currently enrolled in a formal, degree...
# EmploymentStatus                  Which of the following best describes your cur...
# FormalEducation                   Which of the following best describes the high...
# MajorUndergrad                    Which of the following best describes your mai...
# HomeRemote                             How often do you work from home or remotely?
# CompanySize                       In terms of the number of employees, how large...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                                            Question
# Column
# YearsProgram                      How long has it been since you first learned h...
# YearsCodedJobPast                 For how many years did you code as part of you...
# YearsCodedJob                     For how many years have you coded as part of y...
# WorkStart                         Suppose you could choose your own working hour...
# WorkPayCare                       I don't really care what I work on, so long as...
# WebDeveloperType                  Which of the following best describes you as a...
# WantWorkPlatform                  Which of the following platforms have you done...
# WantWorkLanguage                  Which of the following languages have you done...
# WantWorkFramework                 Which of the following libraries, frameworks, ...
# WantWorkDatabase                  Which of the following database technologies h...
# ...

# %%
schema_df
# Out:
#                                                                            Question
# Column
# Respondent                                                     Respondent ID number
# Professional                             Which of the following best describes you?
# ProgramHobby                      Do you program as a hobby or contribute to ope...
# Country                                     In which country do you currently live?
# University                        Are you currently enrolled in a formal, degree...
# EmploymentStatus                  Which of the following best describes your cur...
# FormalEducation                   Which of the following best describes the high...
# MajorUndergrad                    Which of the following best describes your mai...
# HomeRemote                             How often do you work from home or remotely?
# CompanySize                       In terms of the number of employees, how large...
# ...

# %%
schema_df.sort_index(ascending=True)
# Out:
#                                                                            Question
# Column
# AnnoyingUI                                 It annoys me when software has a poor UI
# AssessJobCommute                  When you're assessing potential jobs to apply ...
# AssessJobCompensation             When you're assessing potential jobs to apply ...
# AssessJobDept                     When you're assessing potential jobs to apply ...
# AssessJobDiversity                When you're assessing potential jobs to apply ...
# AssessJobExp                      When you're assessing potential jobs to apply ...
# AssessJobFinances                 When you're assessing potential jobs to apply ...
# AssessJobIndustry                 When you're assessing potential jobs to apply ...
# AssessJobLeaders                  When you're assessing potential jobs to apply ...
# AssessJobOffice                   When you're assessing potential jobs to apply ...
# ...

# %%
schema_df.columns
# Out:
# Index(['Question'], dtype='object')

# %%
schema_df.index
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', name='Column', length=154)

# %%
pd.set_option("display.max_rows",154)

# %%
schema_df.index
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', name='Column', length=154)

# %%
schema_df.loc["CompanySize"]
# Out:
# Question    In terms of the number of employees, how large...
# Name: CompanySize, dtype: object

# %%
schema_df.sort_index()
# Out:
#                                                                            Question
# Column
# AnnoyingUI                                 It annoys me when software has a poor UI
# AssessJobCommute                  When you're assessing potential jobs to apply ...
# AssessJobCompensation             When you're assessing potential jobs to apply ...
# AssessJobDept                     When you're assessing potential jobs to apply ...
# AssessJobDiversity                When you're assessing potential jobs to apply ...
# AssessJobExp                      When you're assessing potential jobs to apply ...
# AssessJobFinances                 When you're assessing potential jobs to apply ...
# AssessJobIndustry                 When you're assessing potential jobs to apply ...
# AssessJobLeaders                  When you're assessing potential jobs to apply ...
# AssessJobOffice                   When you're assessing potential jobs to apply ...
# ...

# %%
schema_df.loc["Country"]
# Out:
# Question    In which country do you currently live?
# Name: Country, dtype: object

# %%
schema_df.loc["Salary"].value_counts().plot(kind="line")

# %%
df["Salary"].value_counts().plot(kind="bar")

# %%
Sal_above_6K=df[df["Salary"]>100000]

# %%
Sal_above_6K
# Out:
#                       Professional                               ProgramHobby  \
# Respondent
# 3           Professional developer                                  Yes, both
# 18          Professional developer                                  Yes, both
# 23          Professional developer                                         No
# 26          Professional developer                  Yes, I program as a hobby
# 38          Professional developer                                  Yes, both
# 73          Professional developer                                  Yes, both
# ...                            ...                                        ...
# 51309       Professional developer                                         No
# 51312       Professional developer                                         No
# 51313       Professional developer                                         No
# 51316       Professional developer                                  Yes, both
# ...

# %%
df.shape
# Out:
# (51392, 153)

# %%
Sal_above_6K.shape
# Out:
# (1895, 153)

# %%
list_of_countries=["US","UK","India","Germany","Canada"]

# %%
listed_countries_df=df[df["Country"].isin(list_of_countries)]

# %%
listed_countries_df.sort_index()
# Out:
#                       Professional                               ProgramHobby  \
# Respondent
# 12          Professional developer                                         No
# 14          Professional developer                                  Yes, both
# 27          Professional developer                                         No
# 33                   None of these  Yes, I contribute to open source projects
# 38          Professional developer                                  Yes, both
# 55          Professional developer                                         No
# ...                            ...                                        ...
# 51349       Professional developer  Yes, I contribute to open source projects
# 51351       Professional developer                  Yes, I program as a hobby
# 51362       Professional developer                  Yes, I program as a hobby
# 51365       Professional developer  Yes, I contribute to open source projects
# ...

# %%
listed_countries_df["Country"].value_counts()
# Out:
# India      5197
# Germany    4143
# Canada     2233
# Name: Country, dtype: int64

# %%
listed_countries_df["Country"].value_counts().plot(kind="bar")

# %%
df["Country"].value_counts()
# Out:
# United States      11455
# India               5197
# United Kingdom      4395
# Germany             4143
# Canada              2233
# France              1740
#                    ...
# Seychelles             1
# Pitcairn Island        1
# French Guyana          1
# Gabon                  1
# Monaco                 1
# Saint Helena           1
# Name: Country, Length: 201, dtype: int64

# %%
df.columns
# Out:
# Index(['Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize', 'CompanyType',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=153)

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df.columns
# Out:
# Index(['professional', 'programhobby', 'country', 'university',
#        'employmentstatus', 'formaleducation', 'majorundergrad', 'homeremote',
#        'companysize', 'companytype',
#        ...
#        'stackoverflowmakemoney', 'gender', 'highesteducationparents', 'race',
#        'surveylong', 'questionsinteresting', 'questionsconfusing',
#        'interestedanswers', 'salary', 'expectedsalary'],
#       dtype='object', length=153)

# %%
df
# Out:
#                                                  professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
# 6                                                     Student
# ...                                                       ...
# 51387                                  Professional developer
# 51388                                  Professional developer
# 51389                                                 Student
# 51390                                  Professional developer
# 51391                                  Professional developer
# 51392       Professional non-developer who sometimes write...
#
#                          programhobby         country      university  \
# ...

# %%
listed_countries_df
# Out:
#                       Professional                               ProgramHobby  \
# Respondent
# 12          Professional developer                                         No
# 14          Professional developer                                  Yes, both
# 27          Professional developer                                         No
# 33                   None of these  Yes, I contribute to open source projects
# 38          Professional developer                                  Yes, both
# 55          Professional developer                                         No
# ...                            ...                                        ...
# 51349       Professional developer  Yes, I contribute to open source projects
# 51351       Professional developer                  Yes, I program as a hobby
# 51362       Professional developer                  Yes, I program as a hobby
# 51365       Professional developer  Yes, I contribute to open source projects
# ...

# %%
list_cols=df.columns.values.tolist()

# %%
list_cols
# Out:
# ['professional',
#  'programhobby',
#  'country',
#  'university',
#  'employmentstatus',
#  'formaleducation',
#  'majorundergrad',
#  'homeremote',
#  'companysize',
#  'companytype',
#  'yearsprogram',
#  'yearscodedjob',
#  'yearscodedjobpast',
#  'developertype',
#  'webdevelopertype',
#  'mobiledevelopertype',
#  'nondevelopertype',
#  'careersatisfaction',
#  'jobsatisfaction',
#  'excoderreturn',
#  'excodernotforme',
#  'excoderbalance',
#  'excoder10years',
#  'excoderbelonged',
#  'excoderskills',
#  'excoderwillnotcode',
#  'excoderactive',
#  'pronouncegif',
#  'problemsolving',
#  'buildingthings',
#  'learningnewtech',
#  'boringdetails',
#  'jobsecurity',
#  'diversityimportant',
#  'annoyingui',
#  'friendsdevelopers',
#  'rightwrongway',
#  'understandcomputers',
#  'seriouswork',
#  'investtimetools',
#  'workpaycare',
#  'kinshipdevelopers',
#  'challengemyself',
#  'competepeers',
#  'changeworld',
#  'jobseekingstatus',
#  'hoursperweek',
#  'lastnewjob',
# ...

# %%
schema_df.columns
# Out:
# Index(['Question'], dtype='object')

# %%
schema_df.rename(columns={"Question":"Querry"})
# Out:
#                                                                              Querry
# Column
# Respondent                                                     Respondent ID number
# Professional                             Which of the following best describes you?
# ProgramHobby                      Do you program as a hobby or contribute to ope...
# Country                                     In which country do you currently live?
# University                        Are you currently enrolled in a formal, degree...
# EmploymentStatus                  Which of the following best describes your cur...
# FormalEducation                   Which of the following best describes the high...
# MajorUndergrad                    Which of the following best describes your mai...
# HomeRemote                             How often do you work from home or remotely?
# CompanySize                       In terms of the number of employees, how large...
# ...

# %%
schema_df.columns
# Out:
# Index(['Question'], dtype='object')

# %%
schema_df.rename(columns={"Question":"Querry"},inplace=True)

# %%
schema_df.columns
# Out:
# Index(['Querry'], dtype='object')

# %%
df.columns
# Out:
# Index(['professional', 'programhobby', 'country', 'university',
#        'employmentstatus', 'formaleducation', 'majorundergrad', 'homeremote',
#        'companysize', 'companytype',
#        ...
#        'stackoverflowmakemoney', 'gender', 'highesteducationparents', 'race',
#        'surveylong', 'questionsinteresting', 'questionsconfusing',
#        'interestedanswers', 'salary', 'expectedsalary'],
#       dtype='object', length=153)

# %%
df["programhobby"].map({"Yes":True,"No":False})
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
#          ...
# 51387      NaN
# 51388      NaN
# 51389    False
# 51390      NaN
# 51391      NaN
# 51392    False
# Name: programhobby, Length: 51392, dtype: object

# %%
df["programhobby"]
# Out:
# Respondent
# 1                        Yes, both
# 2                        Yes, both
# 3                        Yes, both
# 4                        Yes, both
# 5        Yes, I program as a hobby
# 6                        Yes, both
#                    ...
# 51387                    Yes, both
# 51388    Yes, I program as a hobby
# 51389                           No
# 51390    Yes, I program as a hobby
# 51391    Yes, I program as a hobby
# 51392                           No
# Name: programhobby, Length: 51392, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51392 entries, 1 to 51392
# Columns: 153 entries, professional to expectedsalary
# dtypes: float64(6), object(147)
# memory usage: 60.4+ MB

# %%
df
# Out:
#                                                  professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
# 6                                                     Student
# ...                                                       ...
# 51387                                  Professional developer
# 51388                                  Professional developer
# 51389                                                 Student
# 51390                                  Professional developer
# 51391                                  Professional developer
# 51392       Professional non-developer who sometimes write...
#
#                          programhobby         country      university  \
# ...

# %%
type(df["salary"])
# Out:
# pandas.core.series.Series

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (51392, 153)

# %%
df["salary"].astype(str)
# Out:
# Respondent
# 1             nan
# 2             nan
# 3        113750.0
# 4             nan
# 5             nan
# 6             nan
#            ...
# 51387         nan
# 51388     58000.0
# 51389         nan
# 51390         nan
# 51391     40000.0
# 51392         nan
# Name: salary, Length: 51392, dtype: object

# %%
df["country"].astype(str)
# Out:
# Respondent
# 1         United States
# 2        United Kingdom
# 3        United Kingdom
# 4         United States
# 5           Switzerland
# 6           New Zealand
#               ...
# 51387           Romania
# 51388     United States
# 51389         Venezuela
# 51390            Canada
# 51391     United States
# 51392           Ireland
# Name: country, Length: 51392, dtype: object

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df.head(2)
# Out:
#            professional programhobby         country      university  \
# Respondent
# 1               Student    Yes, both   United States              No
# 2               Student    Yes, both  United Kingdom  Yes, full-time
#
#                                   employmentstatus  \
# Respondent
# 1           Not employed, and not looking for work
# 2                               Employed part-time
#
#                                               formaleducation  \
# Respondent
# 1                                            Secondary school
# 2           Some college/university study without earning ...
#
#                                       majorundergrad  \
# Respondent
# 1                                                NaN
# 2           Computer science or software engineering
#
#                                        homeremote         companysize  \
# Respondent
# 1                                             NaN                 NaN
# ...

# %%
df.columns
# Out:
# Index(['professional', 'programhobby', 'country', 'university',
#        'employmentstatus', 'formaleducation', 'majorundergrad', 'homeremote',
#        'companysize', 'companytype',
#        ...
#        'stackoverflowmakemoney', 'gender', 'highesteducationparents', 'race',
#        'surveylong', 'questionsinteresting', 'questionsconfusing',
#        'interestedanswers', 'salary', 'expectedsalary'],
#       dtype='object', length=153)

# %%
df["new_col"]=df["country"]+" "+df["professional"]

# %%
df.head(2)
# Out:
#            professional programhobby         country      university  \
# Respondent
# 1               Student    Yes, both   United States              No
# 2               Student    Yes, both  United Kingdom  Yes, full-time
#
#                                   employmentstatus  \
# Respondent
# 1           Not employed, and not looking for work
# 2                               Employed part-time
#
#                                               formaleducation  \
# Respondent
# 1                                            Secondary school
# 2           Some college/university study without earning ...
#
#                                       majorundergrad  \
# Respondent
# 1                                                NaN
# 2           Computer science or software engineering
#
#                                        homeremote         companysize  \
# Respondent
# 1                                             NaN                 NaN
# ...

# %%
country_grp=df.groupby(["country"])

# %%
country_grp.head(20)
# Out:
#                                                  professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
# 6                                                     Student
# ...                                                       ...
# 51073                                  Professional developer
# 51092       Professional non-developer who sometimes write...
# 51221                                  Professional developer
# 51228                                                 Student
# 51301                                                 Student
# 51354                                  Professional developer
#
#                                          programhobby                 country  \
# ...

# %%
df["country"].value_counts()
# Out:
# United States      11455
# India               5197
# United Kingdom      4395
# Germany             4143
# Canada              2233
# France              1740
#                    ...
# Seychelles             1
# Pitcairn Island        1
# French Guyana          1
# Gabon                  1
# Monaco                 1
# Saint Helena           1
# Name: country, Length: 201, dtype: int64

# %%
country_grp.get_group("United Kingdom")
# Out:
#                                    professional               programhobby  \
# Respondent
# 2                                       Student                  Yes, both
# 3                        Professional developer                  Yes, both
# 13          Used to be a professional developer  Yes, I program as a hobby
# 15                       Professional developer  Yes, I program as a hobby
# 17                       Professional developer                  Yes, both
# 22                       Professional developer  Yes, I program as a hobby
# ...                                         ...                        ...
# 51356                    Professional developer                  Yes, both
# 51371                    Professional developer  Yes, I program as a hobby
# 51373                    Professional developer  Yes, I program as a hobby
# 51376                    Professional developer                         No
# ...

# %%
two_col_grps=df.groupby(["country","university"])

# %%
two_col_grps.head()
# Out:
#                                                  professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
# 6                                                     Student
# ...                                                       ...
# 51286                                                 Student
# 51301                                                 Student
# 51321       Professional non-developer who sometimes write...
# 51343       Professional non-developer who sometimes write...
# 51354                                  Professional developer
# 51364                                  Professional developer
#
#                          programhobby         country           university  \
# ...

# %%
two_col_grps.first()
# Out:
#                                                                         professional  \
# country       university
# Afghanistan   I prefer not to say                             Professional developer
#               No                                              Professional developer
#               Yes, full-time                                                 Student
#               Yes, part-time                                  Professional developer
# Aland Islands I prefer not to say                                      None of these
#               No                                              Professional developer
# ...                                                                              ...
# Zambia        Yes, full-time                                  Professional developer
#               Yes, part-time       Professional non-developer who sometimes write...
# Zimbabwe      I prefer not to say                             Professional developer
# ...
