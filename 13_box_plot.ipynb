# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales_technology=np.random.randint(1,100,10)
sales_office_supplies=np.random.randint(1,100,10)
sales_furniture=np.random.randint(1,100,10)

# %%
plt.figure(figsize=(10,7))
plt.boxplot([sales_technology,sales_office_supplies,sales_furniture])
plt.show()
