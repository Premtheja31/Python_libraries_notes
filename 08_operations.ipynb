# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df["col2"].unique()
# Out:
# array([444, 555, 666])

# %%
df["col3"].unique()
# Out:
# array(['abc', 'def', 'ghi', 'xyz'], dtype=object)

# %%
df["col3"].nunique()
# Out:
# 4

# %%
df[(df["col2"] >500) & (df["col2"]<600)]
# Out:
#    col1  col2 col3
# 1     2   555  def

# %%
df[df["col2"].between(500,600)]
# Out:
#    col1  col2 col3
# 1     2   555  def

# %%
df["col4"]=df["col1"]**2

# %%
df
# Out:
#    col1  col2 col3  col4
# 0     1   444  abc     1
# 1     2   555  def     4
# 2     3   666  ghi     9
# 3     4   444  xyz    16

# %%
def l(x):
  return len(x)

# %%
df["col5"]=df["col3"].apply(lambda x:l(x))

# %%
df
# Out:
#    col1  col2 col3  col4  col5
# 0     1   444  abc     1     3
# 1     2   555  def     4     3
# 2     3   666  ghi     9     3
# 3     4   444  xyz    16     3

# %%
del df["col5"]

# %%
df
# Out:
#    col1  col2 col3  col4
# 0     1   444  abc     1
# 1     2   555  def     4
# 2     3   666  ghi     9
# 3     4   444  xyz    16
