# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/excel files/2_pandas_weather_data.csv")

# %%
df
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017           32          6   Rain
# 1  02-01-2017           35          7  Sunny
# 2  03-01-2017           28          2   Snow

# %%
dfe=pd.read_excel("/content/drive/MyDrive/excel files/2_pandas_weather_data.xlsx")

# %%
dfe
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
weather_data = {'day': ['1/1/2017','1/2/2017','1/3/2017'],'temperature': [32,35,28],'windspeed': [6,7,2],'event': ['Rain', 'Sunny', 'Snow']}

# %%
weather_df=pd.DataFrame(weather_data)

# %%
weather_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# creating a data frame using list of dictionaries

# %%
weather_data = [{'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},{'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},{'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},]

# %%
weather_df_dict=pd.DataFrame(data=weather_data,columns=["day","temperature","windspeed","event"])

# %%
weather_df_dict
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
